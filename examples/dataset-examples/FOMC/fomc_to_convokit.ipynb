# %% [markdown]
# # Converting FOMC Dataset into the ConvoKit Format
#
# This notebook helps constructing a Convokit-formatted version of the dataset originally distributed with the following paper:
#
# [Talk it up or play it down? (Un)expected correlations between (de-)emphasis and recurrence of discussion points in consequential U.S. economic policy meetings. Chenhao Tan and Lillian Lee. Presented in Text As Data 2016](https://chenhaot.com/papers/de-emphasis-fomc.html).
#
# Please cite this paper when using this corpus in your research.
#
# **Main Contributors:** Johan Michalove, Joy Ming, Austen Mack-Crane
#
# **Conversion Notebook Contributors:** Johan Michalove, Joy Ming, Austen Mack-Crane, Yash Chatha, Sean Zhang
#
# **Original Dataset:** [FOMC](https://chenhaot.com/pages/de-emphasis-fomc.html)

# %% [markdown]
# ## Installation and Setup

# %%
# For Colab
# try:
#     import convokit
# except ModuleNotFoundError:
#     !pip install convokit

# %%
import convokit
from tqdm import tqdm
from convokit import Corpus, Speaker, Utterance
from collections import defaultdict

# %% [markdown]
# ## Downloading the Data

# %%
# For Colab

# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_to_data = "/content/drive/My Drive/fomc_transcripts.jsonlist"
with open(path_to_data, "r", encoding='utf-8', errors='ignore') as f:
    fomc_transcripts = f.readlines()

# %%
import json
data = [json.loads(l) for l in fomc_transcripts]
# Out:
# 268

# %%
print(data[0])
# Out:
# {'date': 19770118, 'speeches': [{'text': "Gentlemen, this meeting will now come to order, please. There are several items that I thought would be best taken up in executive session. And one of them is the agreement concluded by the central bankers in Basel concerning the establishment of a facility for handling official sterling balances. The agreement has been distributed to the members of the Committee. I hope you've all had an opportunity to review it. I'll call on Governor Wallich to summarize the essentials of this agreement in a few sentences. And then we will discuss it, and at the end of our discussion, I hope that someone will be good enough to move ratification of the agreement. Mr. Wallich, please.", 'sentences': [{'lemmas': 'gentleman , this meeting will now come to order , please .', 'ners': 'o o o o o date o o o o o o', 'pos_tags': 'nns , dt nn md rb vb to vb , vb .', 'words': 'gentlemen , this meeting will now come to order , please .'}, {'lemmas': 'there be several item that i think would be best take up in executive session .', 'ners': 'o o o o o o o o o o o o o o o o', 'pos_tags': 'ex vbp jj nns in prp vbd md vb jjs vbn rp in nn nn .', 'words': 'there are several items that i thought would be best taken up in executive session .'}, {'lemmas': 'and one of they be the agreement conclude by the central banker in basel concern the establishment of a facility for handle official sterling balance .', 'ners': 'o number o o o o o o o o o o o location o o o o o o o o o o o o', 'pos_tags': 'cc cd in prp vbz dt nn vbn in dt jj nns in nnp vbg dt nn in dt nn in vbg jj nn nns .', 'words': 'and one of them is the agreement concluded by the central bankers in basel concerning the establishment of a facility for handling official sterling balances .'}, {'lemmas': 'the agreement have be distribute to the member of the committee .', 'ners': 'o o o o o o o o o o o o', 'pos_tags': 'dt nn vbz vbn vbn to dt nns in dt nnp .', 'words': 'the agreement has been distributed to the members of the committee .'}, {'lemmas': 'i hope you have all have a opportunity to review it .', 'ners': 'o o o o o o o o o o o o', 'pos_tags': 'prp vbp prp vbp dt vbd dt nn to vb prp .', 'words': "i hope you 've all had an opportunity to review it ."}, {'lemmas': "i 'll call on governor wallich to summarize the essential of this agreement in a few sentence .", 'ners': 'o o o o o person o o o o o o o o o o o o', 'pos_tags': 'prp md vb in nnp nnp to vb dt nns in dt nn in dt jj nns .', 'words': "i 'll call on governor wallich to summarize the essentials of this agreement in a few sentences ."}, {'lemmas': 'and then we will discuss it , and at the end of we discussion , i hope that someone will be good enough to move ratification of the agreement .', 'ners': 'o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o', 'pos_tags': 'cc rb prp md vb prp , cc in dt nn in prp$ nn , prp vbp in nn md vb jj rb to vb nn in dt nn .', 'words': 'and then we will discuss it , and at the end of our discussion , i hope that someone will be good enough to move ratification of the agreement .'}, {'lemmas': 'mr. wallich , please .', 'ners': 'o person o o o', 'pos_tags': 'nnp nnp , vb .', 'words': 'mr. wallich , please .'}], 'speaker': 'CHAIRMAN BURNS.', 'speech_index': 1}, {'text': "The purpose of the agreement--which exists in principle, and its main components remain to be finalized in a few details--is to reduce official sterling balances. These have been a disturbing element due to their volatility. The agreement provides that the BIS [Bank for International Settlements] will finance the Bank of England to the extent that these balances are reduced, except by bond funding and to the extent that the British reserves simultaneously go down. The details are to be worked out. If the BIS cannot fully carry through that financing, it has a fallback with respect to the participating central banks. Now, the Bank of England is committed to use its best efforts to reduce official ste ...

# %%
speaker_names = set()
# TODO: lowercase names, take out spaces

for meeting in data:
  speeches = meeting['speeches']
  for speech in speeches:
    speaker_names.add(speech['speaker'])

# %%
print(speaker_names)
# Out:
# {'M R . COLDWELL.', 'MR. SIMPSON.', 'MR.   MAYO.', 'MR. SANTOMERO.', 'VICE CHAIRMAN MCDONOUGH.', 'MR. SHEETS.', 'MR. JOHNSON.', 'MR. MOSKOW.', 'MS. KOLE.', 'MR. MELZER.', 'MS. MINEHAN AND OTHERS.', 'MR. BEEBE.', 'MS. BIES.', 'MR.   TRUMAN.', "MR. O'CONNELL.", 'MR. BRAYTON.', 'M R . BALLES.', 'MR.   SYRON.', 'MR. GARDNER.', 'GOVERNOR JOHNSON.', 'M R . PARDEE.', 'MR SHEETS.', 'MR. BLACK.', 'MS. YELLEN.', 'MR. ROOS.', 'MR. EVANS.', 'MR. PORTER.', 'MR.   LINDSEY.', 'MR. DAVIS.', 'MR. BOHNE.', 'MS.   GREENE.', 'MR. PARKINSON.', 'MR.   STERNLIGHT.', 'MR. PLOSSER.', 'MR. SLIFMAN.', 'MR.   BLACK.', 'MR.   ALTMANN.', 'MR. DOYLE.', 'CHAIRMAN VOLCKER.', 'MR. MCDONALD.', 'MS. PHILLIPS.', 'MR. ROBINSON.', 'MR. ALTMANN.', 'MR. AHMED.', 'MS. MOSSER.', 'MR. PARRY.', 'MR. KEEHN.', 'MR. HOENIG.', 'VICE CHAIRMAN SOLOMON ET AL.', 'MR. ALTMANN .', 'VICE CHAIRMAN VOLCKER.', 'MR. RUDEBUSCH.', 'MR. MAYO.', 'CHAIRMAN MILLER.', 'M R . AXILROD.', 'MR. MANNION.', 'MR. LEAHY.', 'MR.    RICE.', 'MR. CZERWINSKI.', 'MR. STOCKTON.', 'MR. MADIGAN.', 'GOVERNOR KELLEY.', 'MR KOHN.', 'MR. BRADFIELD.', 'MR. CROSS.', 'M R . BLACK.', 'MR. GRAMLEY.', 'MR. TETLOW.', 'MR. GRALEY.', 'MR. FERGUSON.', 'MESSRS. TRUMAN AND PRELL.', 'MR. LAWARE.', 'MR. ALVAREZ.', 'MR. MATTINGLY.', 'MR. BASSETT.', 'MR.   AXILROD.', 'MR. WILLIS.', 'MR. FOSSUM.', 'MS.   TEETERS.', 'MR.   COLDWELL.', 'MR. KERAN.', 'MS. KRIEGER.', 'MR. PHILLIPS.', 'MR. KROSZNER.', 'GOVERNOR KOHN.', 'MS. LIANG.', 'MR. VAN NICE.', 'VICE CHAIRMAN VOLCKER AND MR. GARDNER.', 'MR. PATRIKIS.', 'MR.   PARDEE.', 'MR. LINDSEY.', 'MR. BERNARD.', 'SPEAKERS(?).', 'MR. ETTIN.', 'MR. REYNOLDS.', 'PRESIDENT GUYNN.', 'MS. GOLDBERG.', 'MR. HILTON.', 'MR.   BALLES.', 'GOVERNOR LAWARE.', 'MR. MACDONALD.', 'MR. SIEGMAN.', 'MR. KAMIN.', 'MS. HOLCOMB.', 'MR. JORDAN.', 'MR. GIBSON.', 'MR. KOHN.', 'M R . ROOS.', 'MS. HORN.', 'M R . MORRIS.', 'MR. ENGLISH.', 'CHAIRMAN BURNS AND MR. COLDWELL.', 'M R . WILLES.', 'MR. GRAMLICH.', 'MR. BALLES.', 'MR. STEWART.', 'MR. SYRON.', 'MR. FUHRER.', 'MR. WHITESELL.', 'MR. TIMLEN.', 'MR. MORRIS.', 'MR. OLSON.', 'MR.   RICE.', 'M R . GAINOR.', 'MR. BOYKIN.', 'MR. GEITHNER.', 'SPEAKER (?).', 'MS. PIANALTO.', 'MR. LANG.', 'MR. PETERS.', 'SEVERAL MEMBERS.', 'MR. PETERSEN.', 'MR. ENZLER.', 'GOVERNOR MEYER.', 'MR. MEEK.', 'MR. FORD.', 'MR ANGELL.', 'GOVERNOR ANGELL.', 'MR. HELLER.', 'MR. GREENLEE.', 'MS. TEETERS.', 'VICE CHAIRMAN GREENSPAN.', 'PRESIDENT BALLES.', 'PRESIDENT BROADDUS.', 'MS. HIRTLE.', 'MR.   ROOS.', 'MS. GREENE.', 'MR. ROBERTS.', 'MR. DENKLER.', 'MR. FARNSWORTH.', 'MS JOHNSON.', 'MR. LACKER.', 'VICE CHAIRMAN CORRIGAN.', 'MR.   GRAMLEY.', 'M R . SMOOT.', 'MR.   MORRIS.', 'MR WILCOX.', 'MR. FORRESTAL.', 'MR. HOSKINS.', 'MR. SPILLENKOTHEN.', 'MR.   EASTBURN.', 'MS.   ZICKLER.', 'MR. HENDRICKS.', 'MR. GRIFFITH.', 'MR. CROUSHORE.', 'MR. BERNANKE.', 'MR. MCDONOUGH.', 'MR. ELMENDORF.', 'MR. CLOUSE.', 'MS TEETERS.', 'MS.    TEETERS.', 'MS. ZICKLER.', 'M R . HOLMES.', 'MS.   SEGER.', 'MR.    BLACK.', 'MR. EASTBURN.', 'MS. DUKE.', 'MR. BOEHNE.', 'MS. MINEHAN.', 'GOVERNOR GREENSPAN.', 'MR. HOWARD.', 'MR. VOLCKER.', 'M R . BAUGHMAN.', 'MR. RICE.', 'MR.   MELZER.', 'MR. LOCKHART.', 'MR. BAUGHMAN.', 'MR. GALLIN.', 'MR. REIFSCHNEIDER.', 'MS. SEGER.', 'MR. ROSINE.', 'M R . WINN.', 'M R . RICE.', 'MR. GOODFRIEND.', 'MR. WALLJCH.', 'MR FISHER.', 'MR. WILLES.', 'MR. WARSH.', 'MR.    WALLICH.', 'MS. DRIGGINS.', 'MR. WINN .', 'MR. MONHOLLON.', 'M R . WALLICH.', 'MR. SMOOT.', 'M R . ALTMANN.', 'MR. JACKSON.', 'MR.   FISHER.', 'MS. FOX.', 'MR. HOLMES.', 'GOVERNOR KROSZNER.', 'MR. GILLUM.', 'PRESIDENT KIMBREL.', 'MR. MOSCOW.', 'M R . ZEISEL.', 'MS. DANKER.', 'MR.   PARRY.', 'MR. RANKIN.', 'MR. PEACH.', 'MR.   HOLMES.', 'MR.   HOSKINS.', 'MR. MORIN.', 'MR. MULLINS.', 'MS. AARONSON.', 'MR. MISHKIN.', 'M R . TRUMAN.', 'MR. TRUMAN.', 'MR. LEBOW.', 'MR. MEYER.', 'MS. JOHNSON.', 'MR.   PARTEE.', 'MR REINHART.', 'MR. KIMBREL.', 'SPEAKER(?).', 'MR. MARTIN.', 'MR. STERNLIGHT.', 'MR. COYNE.', 'PRESIDENT FISHER.', 'MS. SMITH.', ...

# %% [markdown]
# ## Creating Speakers

# %%
corpus_speakers = {speaker: Speaker(id = speaker, meta={'is_chair': "CHAIR" in speaker and "VICE" not in speaker, 'is_vice_chair': 'VICE' in speaker}) for speaker in speaker_names}

# %%
print(corpus_speakers)
# Out:
# {'M R . COLDWELL.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'M R . COLDWELL.'}), 'MR. SIMPSON.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. SIMPSON.'}), 'MR.   MAYO.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR.   MAYO.'}), 'MR. SANTOMERO.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. SANTOMERO.'}), 'VICE CHAIRMAN MCDONOUGH.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': True}, 'vectors': [], 'owner': None, 'id': 'VICE CHAIRMAN MCDONOUGH.'}), 'MR. SHEETS.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. SHEETS.'}), 'MR. JOHNSON.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. JOHNSON.'}), 'MR. MOSKOW.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. MOSKOW.'}), 'MS. KOLE.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MS. KOLE.'}), 'MR. MELZER.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. MELZER.'}), 'MS. MINEHAN AND OTHERS.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MS. MINEHAN AND OTHERS.'}), 'MR. BEEBE.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. BEEBE.'}), 'MS. BIES.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MS. BIES.'}), 'MR.   TRUMAN.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR.   TRUMAN.'}), "MR. O'CONNELL.": Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': "MR. O'CONNELL."}), 'MR. BRAYTON.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. BRAYTON.'}), 'M R . BALLES.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'M R . BALLES.'}), 'MR.   SYRON.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR.   SYRON.'}), 'MR. GARDNER.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. GARDNER.'}), 'GOVERNOR JOHNSON.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'GOVERNOR JOHNSON.'}), 'M R . PARDEE.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'M R . PARDEE.'}), 'MR SHEETS.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR SHEETS.'}), 'MR. BLACK.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. BLACK.'}), 'MS. YELLEN.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MS. YELLEN.'}), 'MR. ROOS.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': None, 'id': 'MR. ROOS.'}), 'MR. EVANS.': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair' ...

# %% [markdown]
# ## Creating Utterance Objects

# %%
from pandas.core.computation.scope import Timestamp
utterance_corpus = {}

for meeting in data:
  speeches = meeting['speeches']
  for speech in speeches:
    idx = "{}_{}".format(meeting['date'], speech['speech_index'])
    speaker = corpus_speakers[speech['speaker']]
    if int(speech['speech_index']) > 1:
      reply_to = "{}_{}".format(meeting['date'], int(speech['speech_index'])-1)
    else:
      reply_to = None
    # Proxy for timestamp, currently not in use
    timestamp = int(meeting['date'])*100000 + int(speech['speech_index'])
    utterance_corpus[idx] = Utterance(id=idx, speaker=speaker, 
                                      text=speech['text'], 
                                      reply_to=reply_to,
                                      timestamp=timestamp,
                                      conversation_id=str(meeting['date']))
    
    # utterance_corpus[idx].add_meta('meeting_date', int(meeting['date']))
    utterance_corpus[idx].add_meta('speech_index', int(speech['speech_index']))

# %%
utterance_corpus['19770118_1']
utterance_corpus['19770118_2']
# Out:
# Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 2}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd2cede4e50>, 'id': 'MR. WALLICH.'}), 'conversation_id': '19770118', 'reply_to': '19770118_1', 'timestamp': None, 'text': "The purpose of the agreement--which exists in principle, and its main components remain to be finalized in a few details--is to reduce official sterling balances. These have been a disturbing element due to their volatility. The agreement provides that the BIS [Bank for International Settlements] will finance the Bank of England to the extent that these balances are reduced, except by bond funding and to the extent that the British reserves simultaneously go down. The details are to be worked out. If the BIS cannot fully carry through that financing, it has a fallback with respect to the participating central banks. Now, the Bank of England is committed to use its best efforts to reduce official sterling balances to working balances. First, by a funding operation offering some of the major holders of official balances 5- to 10- year bonds, 75 percent of which, at a maximum, would be in dollars, the rest in nondollar and nonsterling currencies. Second, whatever is left of the total balances after this operation, [the goal would be] to bring that down to the level of working balances. The detail of that is not described, but it could consist of various administrative measures. Broadly speaking, we're talking about something like PS2 billion sterling, or $3.4 billion [equivalent]; maybe half a billion pounds of that could be funded. Maybe something like PS1 billion might remain as working balances, and the other half billion would have to worked off over time. This is to be done in cooperation with and under the supervision of the Managing Director of the IMF [International Monetary Fund]. The Managing Director of the IMF will confer with the U.K. jointly with the governors of the participating central banks to observe the progress made. Should it turn out that progress is not satisfactory during the two years during which the stand-by agreement is in effect, or if the U.K. should become ineligible to draw under the IMF's stand-by during these two years, then the facility can be suspended. In that case, also, the amounts already drawn will be required to be repaid within 120 days unless the agreement is reconstituted. These are the principle parts of the agreement. Do you want me to go into the Treasury side of this?", 'owner': <convokit.model.corpus.Corpus object at 0x7fd2cede4e50>, 'id': '19770118_2'})

# %% [markdown]
# ## Creating Corpus from List of Utterances

# %%
utterance_list = utterance_corpus.values()
fomc_corpus = Corpus(utterances=utterance_list)

# %% [markdown]
# ## Updating Conversation and Corpus-Level Metadata (skipped)

# %% [markdown]
# ## Processing Utterance Texts

# %%
from convokit.text_processing import TextParser

# %%
parser = TextParser(verbosity=10000)
fomc_corpus = parser.transform(fomc_corpus)
# Out:
# 10000/108504 utterances processed
# 20000/108504 utterances processed
# 30000/108504 utterances processed
# 40000/108504 utterances processed
# 50000/108504 utterances processed
# 60000/108504 utterances processed
# 70000/108504 utterances processed
# 80000/108504 utterances processed
# 90000/108504 utterances processed
# 100000/108504 utterances processed
# 108504/108504 utterances processed

# %%
fomc_corpus.get_utterance('19770118_1').retrieve_meta('parsed')

# %% [markdown]
# ## Saving Created Datasets

# %%
fomc_corpus.dump('fomc-corpus', base_path='/content/drive/My Drive/')

# %% [markdown]
# ## Run stats and check corpus contents

# %%
fomc_corpus.print_summary_stats()
# Out:
# Number of Speakers: 364
# Number of Utterances: 108504
# Number of Conversations: 268

# %%
corpus = fomc_corpus

# %%
corpus.conversations[next(iter(corpus.conversations))]
# Out:
# Conversation({'obj_type': 'conversation', 'meta': {}, 'vectors': [], 'tree': None, 'owner': <convokit.model.corpus.Corpus object at 0x7fd2cede4e50>, 'id': '19770118'})

# %%
corpus.utterances[next(iter(corpus.utterances))]
# Out:
# Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 1, 'parsed': [{'rt': 6, 'toks': [{'tok': 'Gentlemen', 'tag': 'NNS', 'dep': 'npadvmod', 'up': 6, 'dn': []}, {'tok': ',', 'tag': ',', 'dep': 'punct', 'up': 6, 'dn': []}, {'tok': 'this', 'tag': 'DT', 'dep': 'det', 'up': 3, 'dn': []}, {'tok': 'meeting', 'tag': 'NN', 'dep': 'nsubj', 'up': 6, 'dn': [2]}, {'tok': 'will', 'tag': 'MD', 'dep': 'aux', 'up': 6, 'dn': []}, {'tok': 'now', 'tag': 'RB', 'dep': 'advmod', 'up': 6, 'dn': []}, {'tok': 'come', 'tag': 'VB', 'dep': 'ROOT', 'dn': [0, 1, 3, 4, 5, 8, 11]}, {'tok': 'to', 'tag': 'TO', 'dep': 'aux', 'up': 8, 'dn': []}, {'tok': 'order', 'tag': 'VB', 'dep': 'advcl', 'up': 6, 'dn': [7, 9, 10]}, {'tok': ',', 'tag': ',', 'dep': 'punct', 'up': 8, 'dn': []}, {'tok': 'please', 'tag': 'UH', 'dep': 'intj', 'up': 8, 'dn': []}, {'tok': '.', 'tag': '.', 'dep': 'punct', 'up': 6, 'dn': []}]}, {'rt': 1, 'toks': [{'tok': 'There', 'tag': 'EX', 'dep': 'expl', 'up': 1, 'dn': []}, {'tok': 'are', 'tag': 'VBP', 'dep': 'ROOT', 'dn': [0, 3, 15]}, {'tok': 'several', 'tag': 'JJ', 'dep': 'amod', 'up': 3, 'dn': []}, {'tok': 'items', 'tag': 'NNS', 'dep': 'attr', 'up': 1, 'dn': [2, 6]}, {'tok': 'that', 'tag': 'WDT', 'dep': 'nsubj', 'up': 10, 'dn': []}, {'tok': 'I', 'tag': 'PRP', 'dep': 'nsubj', 'up': 6, 'dn': []}, {'tok': 'thought', 'tag': 'VBD', 'dep': 'relcl', 'up': 3, 'dn': [5, 10]}, {'tok': 'would', 'tag': 'MD', 'dep': 'aux', 'up': 10, 'dn': []}, {'tok': 'be', 'tag': 'VB', 'dep': 'auxpass', 'up': 10, 'dn': []}, {'tok': 'best', 'tag': 'RBS', 'dep': 'advmod', 'up': 10, 'dn': []}, {'tok': 'taken', 'tag': 'VBN', 'dep': 'ccomp', 'up': 6, 'dn': [4, 7, 8, 9, 11, 12]}, {'tok': 'up', 'tag': 'RP', 'dep': 'prt', 'up': 10, 'dn': []}, {'tok': 'in', 'tag': 'IN', 'dep': 'prep', 'up': 10, 'dn': [14]}, {'tok': 'executive', 'tag': 'JJ', 'dep': 'amod', 'up': 14, 'dn': []}, {'tok': 'session', 'tag': 'NN', 'dep': 'pobj', 'up': 12, 'dn': [13]}, {'tok': '.', 'tag': '.', 'dep': 'punct', 'up': 1, 'dn': []}]}, {'rt': 4, 'toks': [{'tok': 'And', 'tag': 'CC', 'dep': 'cc', 'up': 4, 'dn': []}, {'tok': 'one', 'tag': 'CD', 'dep': 'nsubj', 'up': 4, 'dn': [2]}, {'tok': 'of', 'tag': 'IN', 'dep': 'prep', 'up': 1, 'dn': [3]}, {'tok': 'them', 'tag': 'PRP', 'dep': 'pobj', 'up': 2, 'dn': []}, {'tok': 'is', 'tag': 'VBZ', 'dep': 'ROOT', 'dn': [0, 1, 6, 25]}, {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 6, 'dn': []}, {'tok': 'agreement', 'tag': 'NN', 'dep': 'attr', 'up': 4, 'dn': [5, 7, 14]}, {'tok': 'concluded', 'tag': 'VBN', 'dep': 'acl', 'up': 6, 'dn': [8]}, {'tok': 'by', 'tag': 'IN', 'dep': 'agent', 'up': 7, 'dn': [11]}, {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 11, 'dn': []}, {'tok': 'central', 'tag': 'JJ', 'dep': 'amod', 'up': 11, 'dn': []}, {'tok': 'bankers', 'tag': 'NNS', 'dep': 'pobj', 'up': 8, 'dn': [9, 10, 12]}, {'tok': 'in', 'tag': 'IN', 'dep': 'prep', 'up': 11, 'dn': [13]}, {'tok': 'Basel', 'tag': 'NNP', 'dep': 'pobj', 'up': 12, 'dn': []}, {'tok': 'concerning', 'tag': 'VBG', 'dep': 'acl', 'up': 6, 'dn': [16]}, {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 16, 'dn': []}, {'tok': 'establishment', 'tag': 'NN', 'dep': 'dobj', 'up': 14, 'dn': [15, 17]}, {'tok': 'of', 'tag': 'IN', 'dep': 'prep', 'up': 16, 'dn': [19]}, {'tok': 'a', 'tag': 'DT', 'dep': 'det', 'up': 19, 'dn': []}, {'tok': 'facility', 'tag': 'NN', 'dep': 'pobj', 'up': 17, 'dn': [18, 20]}, {'tok': 'for', 'tag': 'IN', 'dep': 'prep', 'up': 19, 'dn': [21]}, {'tok': 'handling', 'tag': 'VBG', 'dep': 'pcomp', 'up': 20, 'dn': [24]}, {'tok': 'official', 'tag': 'JJ', 'dep': 'amod', 'up': 24, 'dn': []}, {'tok': 'sterling', 'tag': 'NN', 'dep': 'compound', 'up': 24, 'dn': []}, {'tok': 'balances', 'tag': 'NNS', 'dep': 'dobj', 'up': 21, 'dn': [22, 23]}, {'tok': '.', 'tag': '.', 'dep': 'punct', 'up': 4, 'dn': []}]}, {'rt': 4, 'toks': [{'tok': 'The', 'tag': 'DT', 'dep': 'det', 'up': 1, 'dn': []}, {'tok': 'agreement', 'tag': 'NN', 'dep': 'nsubjpass', 'up': 4, 'dn': [0]}, {'tok': 'has', 'tag': 'VBZ', 'dep': 'aux', 'up': 4, 'dn': []}, {' ...

# %%
next(corpus.iter_speakers()).meta
# Out:
# {'is_chair': True, 'is_vice_chair': False}

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
fomc_corpus.get_conversation('19771018').get_chronological_utterance_list()[:10]
# Out:
# [Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 1}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': True, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'CHAIRMAN BURNS.'}), 'conversation_id': '19771018', 'reply_to': None, 'timestamp': 1977101800001, 'text': "Mr. Gardner is absent today. As far as possible, I would like to have the full Federal Reserve family present at a meeting where quasi-final decisions with regard to monetary policy are made. And in view of that, we can get through as much business as we can this afternoon and stop short of trying to reach any decision of monetary policy; and we have a great deal of work to do. We'll start as we always do, with the minutes of the last meeting, and I take it there is no problem.", 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_1'}),
#  Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 2}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. COLDWELL.'}), 'conversation_id': '19771018', 'reply_to': '19771018_1', 'timestamp': 1977101800002, 'text': 'I move that it be approved.', 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_2'}),
#  Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 3}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. MAYO.'}), 'conversation_id': '19771018', 'reply_to': '19771018_2', 'timestamp': 1977101800003, 'text': 'Second.', 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_3'}),
#  Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 4}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': True, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'CHAIRMAN BURNS.'}), 'conversation_id': '19771018', 'reply_to': '19771018_3', 'timestamp': 1977101800004, 'text': "And that's been accomplished. We will turn at once to a review of the condition of our economy, and we need to examine the condition of our economy with special care at this meeting, not only because this meeting precedes one of our quarterly hearings before the Congress but also because the state of the economy is less clear to many of us, certainly to many observers on the outside, than it was six months ago or perhaps three months ago. Mr. Kichline, would you be good enough to proceed in your own way.", 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_4'}),
#  Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 5}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. KICHLINE.'}), 'conversation_id': '19771018', 'reply_to': '19771018_4', 'timestamp': 1977101800005, 'text': '[Statement--see Appendix.]', 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_5'}),
#  Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 6}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. ZEISEL.'}), 'conversation_id': '19771018', 'reply_to': '19771018_5', 'timestamp': 1977101800006, 'text': '[Statement--see Appendix.]', 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_6'}),
#  Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 7}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': True, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'CHAIRMAN BURNS.'}), 'conversation_id': '19771018', 'reply_to': '19771018_6', 'timestamp': 1977101800007, 'text': "[Interrupting] May I just ask a question? I'm puzzled by that first chart. The black line is below the red line with a few exceptions. What does that first chart mean?", 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_7'}),
#  Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 8}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. ZEISEL.'}), 'conversation_id': '19771018', 'reply_to': '19771018_7', 'timestamp': 1977101800008, 'text': 'A very good point. And my first observation, it appears to me that there may have been a plotting error because one would think it would go directly through.', 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_8'}),
#  Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 9}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': True, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'CHAIRMAN BURNS.'}), 'conversation_id': '19771018', 'reply_to': '19771018_8', 'timestamp': 1977101800009, 'text': "That's the way it used to be done.", 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_9'}),
#  Utterance({'obj_type': 'utterance', 'meta': {'speech_index': 10}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. KICHLINE.'}), 'conversation_id': '19771018', 'reply_to': '19771018_9', 'timestamp': 1977101800010, 'text': "We've introduced some new techniques, but that's not one of them.", 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': '19771018_10'})]

# %%
fomc_corpus.get_conversation('19771018').get_chronological_speaker_list()[:10]
# Out:
# [Speaker({'obj_type': 'speaker', 'meta': {'is_chair': True, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'CHAIRMAN BURNS.'}),
#  Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. COLDWELL.'}),
#  Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. MAYO.'}),
#  Speaker({'obj_type': 'speaker', 'meta': {'is_chair': True, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'CHAIRMAN BURNS.'}),
#  Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. KICHLINE.'}),
#  Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. ZEISEL.'}),
#  Speaker({'obj_type': 'speaker', 'meta': {'is_chair': True, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'CHAIRMAN BURNS.'}),
#  Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. ZEISEL.'}),
#  Speaker({'obj_type': 'speaker', 'meta': {'is_chair': True, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'CHAIRMAN BURNS.'}),
#  Speaker({'obj_type': 'speaker', 'meta': {'is_chair': False, 'is_vice_chair': False}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x7fd17532f850>, 'id': 'MR. KICHLINE.'})]
